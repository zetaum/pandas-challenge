# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_student_combined_df = pd.merge(school_data_df, student_data_df, how="left", on=["school_name"])
school_student_combined_df
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 39165         14  Thomas High School   Charter  1635  1043130       39165
# 39166         14  Thomas High School   Charter  1635  1043130       39166
# 39167         14  Thomas High School   Charter  1635  1043130       39167
# 39168         14  Thomas High School   Charter  1635  1043130       39168
# 39169         14  Thomas High School   Charter  1635  1043130       39169
#
#             student_name gender grade  reading_score  math_score
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#calculate total number of schools
total_number_school = school_student_combined_df['school_name'].value_counts()
#length of the count of each unique school name
num_schools = len(total_number_school)
num_schools
# Out:
# 15

# %%
#calculate total number of students
total_number_students = school_student_combined_df['Student ID'].value_counts()
#length of the count of each unique student ID
total_students = len(total_number_students)
total_students
# Out:
# 39170

# %%
#calculate total budget
group_school_budget = school_student_combined_df.groupby(["school_name"]).mean()
school_budget = group_school_budget['budget'].sum()
school_budget
# Out:
# 24649428.0

# %%
#calculate average math score
avg_math_score = school_student_combined_df['math_score'].mean()
avg_math_score
# Out:
# 78.98537145774827

# %%
#calculate average reading score
avg_reading_score = school_student_combined_df['reading_score'].mean()
avg_reading_score
# Out:
# 81.87784018381414

# %%
#calculate the % of students with a passing math score (70 or greater)
passing_math_score = school_student_combined_df.loc[school_student_combined_df['math_score'] >= 70]['math_score'].count()
perc_passing_math =  (passing_math_score/total_students)*100
perc_passing_math
# Out:
# 74.9808526933878

# %%
#calculate the % of students with a passing reading score (70 or greater)
passing_reading_score = school_student_combined_df.loc[school_student_combined_df['reading_score'] >= 70]['reading_score'].count()
perc_passing_reading =(passing_reading_score/total_students)*100
perc_passing_reading
# Out:
# 85.80546336482001

# %%
#calculate the percentage of students who passed math and reading (% Overall Passing)
overall_pass = (school_student_combined_df[(school_student_combined_df['math_score'] >= 70) & (school_student_combined_df['reading_score'] >= 70)]['student_name'].count()/total_students)*100
overall_pass
# Out:
# 65.17232575950983

# %%
#create a dataframe to hold the above results
district_summary_df = pd.DataFrame({"Total Schools": [num_schools],
                                    "Total Students": [total_students],
                                    "Total School Budget": [school_budget],
                                    "Average Math Score": [avg_math_score],
                                    "Average Reading Score": [avg_reading_score],
                                    "% Passing Math": [perc_passing_math],
                                    "% Passing Reading":[perc_passing_reading],
                                    "% Overall Passing":[overall_pass]
})


district_summary_df
# Out:
#    Total Schools  Total Students  Total School Budget  Average Math Score  \
# 0             15           39170           24649428.0           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
#give the displayed data cleaner formatting
district_summary.style.format({"Total Students": "{:,}", 
                               "Total School Budget": "${:,}", 
                               "Per Student Budget": "${:.0f}",
                               "Average Math Score": "{:.1f}", 
                               "Average Reading Score": "{:.1f}", 
                               "% Passing Math": "{:.1%}", 
                               "% Passing Reading": "{:.1%}", 
                               "% Overall Passing": "{:.1%}"
})
# Out:
# <style  type="text/css" >
# </style><table id="T_c0c8d20a_d077_11ea_8180_acd1b8e2a43c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >%Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0c8d20a_d077_11ea_8180_acd1b8e2a43clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c0c8d20a_d077_11ea_8180_acd1b8e2a43crow0_col0" class="data row0 col0" >15</td>
# ...

# %%
#District Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#set new index to school name
school_type = school_data_df.set_index(["school_name"])["type"]
school_type
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
#total students per school
total_students_per_school = school_student_combined_df["school_name"].value_counts()
total_students_per_school
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
#total school budget
budget_per_school = school_student_combined_df.groupby(["school_name"]).mean()["budget"]
budget_per_school
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
#per student budget 
per_student_budget = budget_per_school/total_students_per_school
per_student_budget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#average math score per school
avg_math_scores = round(school_student_combined_df.groupby(["school_name"]).mean()["math_score"],2)
avg_math_scores
# Out:
# school_name
# Bailey High School       77.05
# Cabrera High School      83.06
# Figueroa High School     76.71
# Ford High School         77.10
# Griffin High School      83.35
# Hernandez High School    77.29
# Holden High School       83.80
# Huang High School        76.63
# Johnson High School      77.07
# Pena High School         83.84
# Rodriguez High School    76.84
# Shelton High School      83.36
# Thomas High School       83.42
# Wilson High School       83.27
# Wright High School       83.68
# Name: math_score, dtype: float64

# %%
#average reading score per school
avg_reading_scores = round(school_student_combined_df.groupby(["school_name"]).mean()["reading_score"],2)
avg_reading_scores
# Out:
# school_name
# Bailey High School       81.03
# Cabrera High School      83.98
# Figueroa High School     81.16
# Ford High School         80.75
# Griffin High School      83.82
# Hernandez High School    80.93
# Holden High School       83.81
# Huang High School        81.18
# Johnson High School      80.97
# Pena High School         84.04
# Rodriguez High School    80.74
# Shelton High School      83.73
# Thomas High School       83.85
# Wilson High School       83.99
# Wright High School       83.96
# Name: reading_score, dtype: float64

# %%
#total students passing math after df merge
students_passing_math = school_student_combined_df[(school_student_combined_df["math_score"]>=70)]

#total students passing math per school
students_passing_math_per_school = students_passing_math.groupby(["school_name"]).count()["student_name"]

#total % students passing math per school
percentage_passing_math_per_school = round((students_passing_math_per_school/total_students_per_school)*100,2)
percentage_passing_math_per_school
# Out:
# Bailey High School       66.68
# Cabrera High School      94.13
# Figueroa High School     65.99
# Ford High School         68.31
# Griffin High School      93.39
# Hernandez High School    66.75
# Holden High School       92.51
# Huang High School        65.68
# Johnson High School      66.06
# Pena High School         94.59
# Rodriguez High School    66.37
# Shelton High School      93.87
# Thomas High School       93.27
# Wilson High School       93.87
# Wright High School       93.33
# dtype: float64

# %%
#total students passing reading after df merge
students_passing_reading = school_student_combined_df[school_student_combined_df["reading_score"]>=70]

#total students passing reading per school
students_passing_reading_per_school = students_passing_reading.groupby(["school_name"]).count()["student_name"]

#total % students passing reading per school
percentage_passing_reading_per_school = round((students_passing_reading_per_school/total_students_per_school)*100,2)
percentage_passing_reading_per_school
# Out:
# Bailey High School       81.93
# Cabrera High School      97.04
# Figueroa High School     80.74
# Ford High School         79.30
# Griffin High School      97.14
# Hernandez High School    80.86
# Holden High School       96.25
# Huang High School        81.32
# Johnson High School      81.22
# Pena High School         95.95
# Rodriguez High School    80.22
# Shelton High School      95.85
# Thomas High School       97.31
# Wilson High School       96.54
# Wright High School       96.61
# dtype: float64

# %%
#overall passing rate per school
overall_passing_rate_per_school = ((percentage_passing_math_per_school + percentage_passing_reading_per_school)/2)
#overall_passing_rate_per_school_perc = (overall_passing_rate_per_school/total_students)*100
overall_passing_rate_per_school
# Out:
# Bailey High School       74.305
# Cabrera High School      95.585
# Figueroa High School     73.365
# Ford High School         73.805
# Griffin High School      95.265
# Hernandez High School    73.805
# Holden High School       94.380
# Huang High School        73.500
# Johnson High School      73.640
# Pena High School         95.270
# Rodriguez High School    73.295
# Shelton High School      94.860
# Thomas High School       95.290
# Wilson High School       95.205
# Wright High School       94.970
# dtype: float64

# %%
#creating a summary of the school data
school_summary_df = pd.DataFrame({"School Type":school_type,
                                  "Total Students":total_students_per_school,
                                  "Total School Budget":budget_per_school,
                                  "Per Student Budget":per_student_budget,
                                  "Average Math Score":avg_math_scores,
                                  "Average Reading Score":avg_reading_scores,
                                  "% Passing Math":percentage_passing_math_per_school,
                                  "% Passing Reading":percentage_passing_reading_per_school,
                                  "% Overall Passing":percentage_passing_reading_per_school})
school_summary_df.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976            3124928.0
# Cabrera High School      Charter            1858            1081356.0
# Figueroa High School    District            2949            1884411.0
# Ford High School        District            2739            1763916.0
# Griffin High School      Charter            1468             917500.0
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0               77.05
# Cabrera High School                582.0               83.06
# Figueroa High School               639.0               76.71
# Ford High School                   644.0               77.10
# Griffin High School                625.0               83.35
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                    81.03           66.68
# ...

# %%
#give the displayed data cleaner formatting
#school_summary_df.style.format({"Total Students": "{:,}", 
                               #"Total School Budget": "${:,}", 
                               #"Per Student Budget": "${:.0f}",
                               #"Average Math Score": "{:.1f}", 
                               #"Average Reading Score": "{:.1f}", 
                               #"% Passing Math": "{:.1%}", 
                               #"% Passing Reading": "{:.1%}", 
                               #"% Overall Passing": "{:.1%}"
#})

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
#top performing schools by % overall passing (5)
top_performing_schools = school_summary_df.sort_values(["% Overall Passing"],ascending = False).head(5)
top_performing_schools
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858            1081356.0
# Thomas High School      Charter            1635            1043130.0
# Pena High School        Charter             962             585858.0
# Griffin High School     Charter            1468             917500.0
# Wilson High School      Charter            2283            1319574.0
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0               83.06
# Thomas High School                638.0               83.42
# Pena High School                  609.0               83.84
# Griffin High School               625.0               83.35
# Wilson High School                578.0               83.27
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School                  83.98           94.13              97.04
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#bottom performing schools by % overall passing (5)
bottom_performing_schools = school_summary_df.sort_values(["% Overall Passing"],ascending = False).tail(5)
bottom_performing_schools
# Out:
#                       School Type  Total Students  Total School Budget  \
# Hernandez High School    District            4635            3022020.0
# Johnson High School      District            4761            3094650.0
# Huang High School        District            2917            1910635.0
# Figueroa High School     District            2949            1884411.0
# Rodriguez High School    District            3999            2547363.0
#
#                        Per Student Budget  Average Math Score  \
# Hernandez High School               652.0               77.29
# Johnson High School                 650.0               77.07
# Huang High School                   655.0               76.63
# Figueroa High School                639.0               76.71
# Rodriguez High School               637.0               76.84
#
#                        Average Reading Score  % Passing Math  \
# Hernandez High School                  80.93           66.75
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %%
#reading score by grade
math_9th=student_data_df.loc[student_data_df["grade"] == "9th"].groupby(["school_name"])['math_score'].mean()
math_9th.head()
math_10th=student_data_df.loc[student_data_df["grade"] == "10th"].groupby(["school_name"])['math_score'].mean()
math_10th.head()
math_11th=student_data_df.loc[student_data_df["grade"] == "11th"].groupby(["school_name"])["math_score"].mean()
math_11th.head()
math_12th=student_data_df.loc[student_data_df["grade"] == "12th"].groupby(["school_name"])["math_score"].mean()
math_12th.head()

#create a DF for Math Scores by Grade
math_byGrad=pd.DataFrame({"9th":math_9th, "10th": math_10th, "11th":math_11th, "12th":math_12th })
math_byGrad
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
read_9th=student_data_df.loc[student_data_df["grade"] == "9th" ].groupby(["school_name"])["reading_score"].mean()
read_9th.head()
read_10th=student_data_df.loc[student_data_df["grade"] == "10th" ].groupby(["school_name"])["reading_score"].mean()
read_10th.head()
read_11th=student_data_df.loc[student_data_df["grade"] == "11th" ].groupby(["school_name"])["reading_score"].mean()
read_11th.head()
read_12th=student_data_df.loc[student_data_df["grade"] == "12th" ].groupby(["school_name"])["reading_score"].mean()
read_12th.head()

#create a DF for read Scores by Grade
read_byGrad=pd.DataFrame({"9th":read_9th, "10th": read_10th, "11th":read_11th, "12th":read_12th })
read_byGrad
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Create 4 bins
bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
school_summary_df["Spending Ranges (Per Student)"]=pd.cut(school_summary_df["Total School Budget"]/school_summary_df["Total Students"]
                                            ,bins , labels=group_names)
school_summary_df.head()
scores_by_sch=school_summary_df.drop(columns=["Total Students", "Total School Budget","School Type", "Per Student Budget"])
scores_by_sch
# Out:
#                        Average Math Score  Average Reading Score  \
# Bailey High School                  77.05                  81.03
# Cabrera High School                 83.06                  83.98
# Figueroa High School                76.71                  81.16
# Ford High School                    77.10                  80.75
# Griffin High School                 83.35                  83.82
# Hernandez High School               77.29                  80.93
# Holden High School                  83.80                  83.81
# Huang High School                   76.63                  81.18
# Johnson High School                 77.07                  80.97
# Pena High School                    83.84                  84.04
# Rodriguez High School               76.84                  80.74
# Shelton High School                 83.36                  83.73
# Thomas High School                  83.42                  83.85
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
